# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name:
# * Student pace: self paced / part time / full time
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:

# %%
# Your code here - remember to use markdown cells for comments as well!

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
import statsmodels
from statsmodels.formula.api import ols
from sklearn.model_selection import train_test_split
from sklearn.dummy import DummyRegressor
from statsmodels.tools.eval_measures import rmse
from statsmodels.api import qqplot
from scipy import stats
from sklearn.preprocessing import OneHotEncoder
from folium.plugins import FastMarkerCluster
import folium
from sklearn.metrics import r2_score

# %%
data = pd.read_csv("data/master_data.csv")

# %%
data[["grade"]]
# Out:
#        grade
# 0          7
# 1          7
# 2          6
# 3          7
# 4          8
# ...      ...
# 21054      8
# 21055      8
# 21056      7
# 21057      8
# 21058      7
#
# [21059 rows x 1 columns]

# %%
dummy_reg = DummyRegressor(strategy = "mean")
dummy_reg.fit(X_train, y_train)
dummy_reg.predict(X_train)
# Out:
# array([538487.51118894, 538487.51118894, 538487.51118894, ...,
#        538487.51118894, 538487.51118894, 538487.51118894])

# %%
dummy_reg.score(X_train, y_train)
# Out:
# 0.0

# %%
data

# %%
y = data["price"]

X = data[["bedrooms", "bathrooms", "sqft_living", "sqft_above", "sqft_living15"]]





X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size = 0.20, 
                                                    random_state = 33)


formula = "price ~ " + " + ".join(X_train)

model = ols(formula=formula, data=data).fit()

model_summary = model.summary()
model_summary
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.515
# Model:                            OLS   Adj. R-squared:                  0.514
# Method:                 Least Squares   F-statistic:                     4463.
# Date:                Tue, 15 Feb 2022   Prob (F-statistic):               0.00
# Time:                        13:53:54   Log-Likelihood:            -2.9216e+05
# No. Observations:               21059   AIC:                         5.843e+05
# Df Residuals:                   21053   BIC:                         5.844e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %% [markdown]
# Check for multicolinearity between sqft living, sqrt above, drop sqrt_above

# %% [markdown]
# 2nd Model

# %%
y = data["price"]

X = data[["bedrooms", "bathrooms", "sqft_living", "sqft_living15"]]





X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size = 0.20, 
                                                    random_state = 33)

formula = "price ~ " + " + ".join(X_train)

model_2 = ols(formula=formula, data=data).fit()

model_summary = model_2.summary()
model_summary
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.512
# Model:                            OLS   Adj. R-squared:                  0.512
# Method:                 Least Squares   F-statistic:                     5528.
# Date:                Tue, 15 Feb 2022   Prob (F-statistic):               0.00
# Time:                        13:53:59   Log-Likelihood:            -2.9221e+05
# No. Observations:               21059   AIC:                         5.844e+05
# Df Residuals:                   21054   BIC:                         5.845e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %% [raw]
# 3rd Model

# %%
y = data["price"]

X = data[["bedrooms", "bathrooms", "sqft_living", "sqft_living15", "grade"]]





X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size = 0.20, 
                                                    random_state = 33)



formula = "price ~ " + " + ".join(X_train)

model_3 = ols(formula=formula, data=data).fit()

model_summary = model_3.summary()
model_summary
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.543
# Model:                            OLS   Adj. R-squared:                  0.542
# Method:                 Least Squares   F-statistic:                     4993.
# Date:                Tue, 15 Feb 2022   Prob (F-statistic):               0.00
# Time:                        13:54:03   Log-Likelihood:            -2.9153e+05
# No. Observations:               21059   AIC:                         5.831e+05
# Df Residuals:                   21053   BIC:                         5.831e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %% [markdown]
# 4th Model

# %% [markdown]
# 5th Model
